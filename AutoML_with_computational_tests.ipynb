# %% [markdown]
# <a href="https://colab.research.google.com/github/GandharvaThite/Auto-ML-for-classification-and-regression/blob/main/AutoML_with_computational_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
import scipy as scipy
from scipy import stats
from sklearn.model_selection import cross_val_score
import timeit

# %%
df = pd.read_csv('/content/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# df = df.drop(0)

# %%
# df = df.drop(columns = ['Symbol','Series','Last','VWAP','Volume','Turnover','Trades','Deliverable Volume','%Deliverble','Date'])
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
type_of_dataset = None
r = df.shape
last_ind = df.columns.values[len(df.columns.values)-1]
total_entries = r[0]-1
set_contents = set(df[last_ind])
gandharva_constant = len(set_contents)/total_entries
if(gandharva_constant>=0.2):
  type_of_dataset = 'regression'
else:
  type_of_dataset = 'classification'
type_of_dataset
# Out:
# 'regression'

# %%
print(gandharva_constant)
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV

X = (df.drop(columns = last_ind,axis = 1))
Y = np.asarray(df[last_ind])
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 1)
X_train
# Out:
#       Prev Close    Open    High     Low
# 1011      164.20  165.00  168.50  164.75
# 1995      276.00  276.10  277.05  274.00
# 2030      270.45  271.00  272.95  269.10
# 1828      295.90  295.80  295.90  286.40
# 2743       46.05   45.80   46.70   43.00
# ...          ...     ...     ...     ...
# 2763       34.25   35.00   37.40   33.35
# 905       161.10  161.85  165.85  160.60
# 1096      147.00  144.50  144.95  140.00
# 235       419.45  420.00  420.00  390.00
# 1061      167.80  169.00  174.20  165.25
#
# [2356 rows x 4 columns]

# %%
# input_data = (0.0139,0.0222,0.0089,0.0108,0.0215,0.0136,0.0659,0.0954,0.0786,0.1015,0.1261,0.0828,0.0493,0.0848,0.1514,0.1396,0.1066,0.1923,0.2991,0.3247,0.3797,0.5658,0.7483,0.8757,0.9048,0.7511,0.6858,0.7043,0.5864,0.3773,0.2206,0.2628,0.2672,0.2907,0.1982,0.2288,0.3186,0.2871,0.2921,0.2806,0.2682,0.2112,0.1513,0.1789,0.1850,0.1717,0.0898,0.0656,0.0445,0.0110,0.0024,0.0062,0.0072,0.0113,0.0012,0.0022,0.0025,0.0059,0.0039,0.0048)
input_data = (76.4, 77, 80.5, 76.5)

# %%
def self_paired_ttest(ttable_val_alpha,arr1,arr2,other):
  print("")
  print("")
  e = []
  add = 0
  add1 = 0
  for i in range(len(arr1)):

    e.append(abs(arr1[i]-arr2[i]))
    add+=(abs(arr1[i]-arr2[i]))
  sample_mean = add/len(arr1)
  for i in range(len(e)):
    add1+=((e[i]-sample_mean)**2)
  sd = (add1/(len(arr1)-1))**0.5
  t_stat = (sample_mean*(len(arr1)**0.5))/sd
  print(t_stat)
  if(-ttable_val_alpha<t_stat and t_stat<ttable_val_alpha):
    print("No significant difference between",algo_names[maxi_ind],"and",other)
    print("Since the value of paired t-test is: ",t_stat,"which falls in range(",-ttable_val_alpha,",",ttable_val_alpha,")")

  else:
    print(algo_names[maxi_ind],"performs better then ",other)
    print("Since the value of paired t-test is: ",t_stat,"which does not fall in range(",-ttable_val_alpha,",",ttable_val_alpha,")")
  print("-------------------------------------------------------------------------------------------------------------------------------")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree


from sklearn.metrics import accuracy_score,confusion_matrix
if(type_of_dataset == 'classification'):
  algo_names = ['svm','random_forest','logistic_regression','decision_tree']
  keys = ['svm','random_forest','logistic_regression','decision_tree']
  algo = [svm.SVC(),RandomForestClassifier(),LogisticRegression(),tree.DecisionTreeClassifier()]
  model_params = {
   'svm':{
   'model':svm.SVC(gamma='auto'),
   'params':{
       'C':[1,10,20],
       'kernel':['linear','poly','rbf']

   }
  } ,
  'random_forest':{
       'model':RandomForestClassifier(),
       'params':{
           'n_estimators':[1,5,10,50,100,150,500,1000]
       }
   },
   'logistic_regression':{
       'model':LogisticRegression(solver = 'liblinear',multi_class='auto'),
       'params':{
          'C':[1,5,10,50,100,150,500,1000]
       }
   },
   'decision_tree':{
       'model':tree.DecisionTreeClassifier(),
       'params':{
           'criterion':['gini','entropy','log_loss'],
           'splitter':['best','random']
       }
   },
    }
  scores = []
  time = []
  for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['params'],cv =5,return_train_score=False)
    start = timeit.default_timer()
    clf.fit(X_train,Y_train)
    stop = timeit.default_timer()
    time.append(stop-start)
    scores.append({
      'model_name':model_name,
      'best_score':clf.best_score_,
      'best_parameters':clf.best_params_
    }
    )
  a = []
  b = []
  final_scores = list(scores)
  for i in range(len(final_scores)):
    a.append(list(final_scores[i].values()))
  for i in range(len(a)):
    b.append(a[i][1])
  maxi_ind = -1
  for i in range(len(b)):
    if(b[i] == max(b)):
      maxi_ind = i
      break
  model = algo[maxi_ind]
  model.fit(X_train,Y_train)
  X_test_prediction = model.predict(X_test)
  ml_final_result_accuracy = accuracy_score(X_test_prediction,Y_test)


  scores_t = []
  for i in range(len(scores)):
    mod = model_params[keys[i]]['model']
    print(mod)
    if scores[i]['best_parameters'] == {}:
      mod.fit(X_train, Y_train)
      scores_t.append(cross_val_score(mod, X, Y, cv=10))
    else:
      mod.set_params(**scores[i]['best_parameters'])
      scores_t.append(cross_val_score(mod, X, Y, cv=10))
  for i in range(len(scores_t)):
    if i ==maxi_ind:
      pass
    else:
      self_paired_ttest(2.262,scores_t[maxi_ind],scores_t[i],algo_names[i])
  input_data_as_np_array = np.asarray(input_data)
  input_data_reshaped = input_data_as_np_array.reshape(1,-1)
  prediction = model.predict(input_data_reshaped)
  prediction[0]

# %%
time
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs

# %%
# Report Printing
if(type_of_dataset == 'classification'):
  arr = ['Model: ','Accuracy: ', 'Parameters Tuned: ']
  print("********************* Report ***********************************")
  print()
  print("Prediction for your values: ",prediction[0])
  print("Type of dataset: ",type_of_dataset)
  for i in range(len(a[maxi_ind])):
    print(arr[i],a[maxi_ind][i])
  print()
  print("****************************************************************")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

if(type_of_dataset == 'regression'):
  algo_names = ['Linear Regression','GBoost Regressor']
  keys = ['linear_regression','gradient_bosting']
  algo = [LinearRegression(),GradientBoostingRegressor()]
  model_params = {
      'linear_regression':{
   'model':LinearRegression(),
   'params':{
      #  'fit_intercept': 1
   }
  } ,
  'gradient_bosting':{
       'model':GradientBoostingRegressor(),
       'params':{
           'n_estimators':[1,5,10,50,100,150,500,1000],
           "learning_rate": [0.01,0.1,0.5]
       }
   },
  }
  scores = []
  time = []
  for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['params'],cv =5,return_train_score=False)
    start = timeit.default_timer()
    clf.fit(X_train,Y_train)
    stop = timeit.default_timer()
    # scores_t.append([cross_val_score(clf, X, Y, cv=10)])
    time.append(stop-start)
    scores.append({
      'model_name':model_name,
      'best_score':clf.best_score_,
      'best_parameters':clf.best_params_
    }
    )

  a = []
  b = []
  final_scores = list(scores)
  for i in range(len(final_scores)):
    a.append(list(final_scores[i].values()))
  for i in range(len(a)):
    b.append(a[i][1])
  maxi_ind = -1
  for i in range(len(b)):
    if(b[i] == max(b)):
      maxi_ind = i
      break
  model = algo[maxi_ind]
  model.fit(X_train,Y_train)
  X_test_prediction = model.predict(X_test)
  # ml_final_result_accuracy = accuracy_score(X_test_prediction,Y_test)
  input_data_as_np_array = np.asarray(input_data)
  input_data_reshaped = input_data_as_np_array.reshape(1,-1)
  prediction = model.predict(input_data_reshaped)
  scores_t = []
  for i in range(len(scores)):
    mod = model_params[keys[i]]['model']
    print(mod)
    if scores[i]['best_parameters'] == {}:
      mod.fit(X_train, Y_train)
      scores_t.append(cross_val_score(mod, X, Y, cv=10))
    else:
      mod.set_params(**scores[i]['best_parameters'])
      scores_t.append(cross_val_score(mod, X, Y, cv=10))
  for i in range(len(scores_t)):
    if i == maxi_ind:
      pass
    else:
      self_paired_ttest(2.262,scores_t[maxi_ind],scores_t[i],algo_names[i])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# LinearRegression()
# GradientBoostingRegressor()
#
#
# 1.2150065760698037
# No significant difference between Linear Regression and GBoost Regressor
# Since the value of paired t-test is:  1.2150065760698037 which falls in range( -2.262 , 2.262 )
# -------------------------------------------------------------------------------------------------------------------------------

# %%
time
# Out:
# [0.02708471699997972, 90.14253467100025]

# %%
# Report Printing
if(type_of_dataset == 'regression'):
  arr = ['Model: ','Accuracy: ', 'Parameters Tuned: ']
  print("********************* Report ***********************************")
  print()
  print("Prediction for your values: ",prediction[0])
  print("Type of dataset: ",type_of_dataset)
  for i in range(len(a[maxi_ind])):
    print(arr[i],a[maxi_ind][i])
  print()
  print("****************************************************************")
# Out:
# ********************* Report ***********************************
#
# Prediction for your values:  79.09918097836223
# Type of dataset:  regression
# Model:  linear_regression
# Accuracy:  0.9996396104878377
# Parameters Tuned:  {}
#
# ****************************************************************
